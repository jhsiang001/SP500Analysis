# %%
import pandas as pd
import numpy as np
from fredapi import Fred
import json
import requests
import time
fred = Fred(api_key='597d1dc605851d73e7f227041c9dba3c')
data = fred.get_series('SP500')

# %%
r = requests.get('https://api.stlouisfed.org/fred/release/series?release_id=51&api_key=597d1dc605851d73e7f227041c9dba3c&file_type=json'
)
len(x)
x = r.json()['seriess']
for i in range(len(x)-490):
    if i % 69 == 0:
        time.sleep(1)
    fred.get_series(x[i]['id'])

# %%
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <seriess realtime_start="2020-07-21" realtime_end="2020-07-21" order_by="series_id" sort_order="asc" count="560" offset="0" limit="1000">
#   <series id="BOMTVLM133S" realtime_start="2020-07-21" realtime_end="2020-07-21" title="U.S. Imports of Services - Travel" observation_start="1992-01-01" observation_end="2017-09-01" frequency="Monthly" frequency_short="M" units="Million of Dollars" units_short="Mil. of $" seasonal_adjustment="Seasonally Adjusted" seasonal_adjustment_short="SA" last_updated="2017-11-03 08:12:15-05" popularity="1" group_popularity="1" notes="Further information related to the international trade data can be found at https://www.census.gov/foreign-trade/data/index.html
# Methodology details can be found at https://www.census.gov/foreign-trade/Press-Release/current_press_release/explain.pdf"/>
# ...
